# %%
import pandas as pd

# %%
m_df = pd.read_csv(
    "../data/ml-latest-small/movies.csv",
)
r_df = pd.read_csv("../data/ml-latest-small/ratings.csv")

# %%
len(m_df)
# Out:
# 9742

# %%
len(m_df["movieId"].unique())
# Out:
# 9742

# %%
m_df["new_MId"] = list(range(len(m_df)))

# %%
m_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  new_MId
# 0  Adventure|Animation|Children|Comedy|Fantasy        0
# 1                   Adventure|Children|Fantasy        1
# 2                               Comedy|Romance        2
# 3                         Comedy|Drama|Romance        3
# 4                                       Comedy        4

# %%
new_df = pd.merge(m_df,r_df,on="movieId")

# %%
r_df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
new_df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    new_MId  userId  rating   timestamp
# 0        0       1     4.0   964982703
# 1        0       5     4.0   847434962
# 2        0       7     4.5  1106635946
# 3        0      15     2.5  1510577970
# 4        0      17     4.5  1305696483

# %%
set(new_df.columns) - set(r_df.columns)
# Out:
# {'genres', 'new_MId', 'title'}

# %%
new_df.drop(["genres","movieId"],axis=1,inplace=True)

# %%
new_df.head()
# Out:
#               title  new_MId  userId  rating   timestamp
# 0  Toy Story (1995)        0       1     4.0   964982703
# 1  Toy Story (1995)        0       5     4.0   847434962
# 2  Toy Story (1995)        0       7     4.5  1106635946
# 3  Toy Story (1995)        0      15     2.5  1510577970
# 4  Toy Story (1995)        0      17     4.5  1305696483

# %%
new_df = new_df.rename(columns={"new_MId":"movieId"})

# %%
new_df.head()
# Out:
#               title  movieId  userId  rating   timestamp
# 0  Toy Story (1995)        0       1     4.0   964982703
# 1  Toy Story (1995)        0       5     4.0   847434962
# 2  Toy Story (1995)        0       7     4.5  1106635946
# 3  Toy Story (1995)        0      15     2.5  1510577970
# 4  Toy Story (1995)        0      17     4.5  1305696483

# %%
new_df.to_csv("../data/processed/data.csv",index=False)

# %%
pd.read_csv("../data/processed/data.csv").columns
# Out:
# Index(['title', 'movieId', 'userId', 'rating', 'timestamp'], dtype='object')

# %%
len(df)
# Out:
# 9742

# %%
192344 in list(df['movieId'])
# Out:
# False

# %%
val = df['userId'].value_counts()
val
# Out:
# userId
# 414    2698
# 599    2478
# 474    2108
# 448    1864
# 274    1346
#        ...
# 320      20
# 207      20
# 257      20
# 569      20
# 576      20
# Name: count, Length: 610, dtype: int64

# %%
val = val[val>=8]
df['userId'].isin(val.index)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 100831    True
# 100832    True
# 100833    True
# 100834    True
# 100835    True
# Name: userId, Length: 100836, dtype: bool

# %%
all_items = list(df["movieId"].unique())
num_items = max(all_items) + 1

# %%
all_items
# Out:
# [np.int64(1),
#  np.int64(3),
#  np.int64(6),
#  np.int64(47),
#  np.int64(50),
#  np.int64(70),
#  np.int64(101),
#  np.int64(110),
#  np.int64(151),
#  np.int64(157),
#  np.int64(163),
#  np.int64(216),
#  np.int64(223),
#  np.int64(231),
#  np.int64(235),
#  np.int64(260),
#  np.int64(296),
#  np.int64(316),
#  np.int64(333),
#  np.int64(349),
#  np.int64(356),
#  np.int64(362),
#  np.int64(367),
#  np.int64(423),
#  np.int64(441),
#  np.int64(457),
#  np.int64(480),
#  np.int64(500),
#  np.int64(527),
#  np.int64(543),
#  np.int64(552),
#  np.int64(553),
#  np.int64(590),
#  np.int64(592),
#  np.int64(593),
#  np.int64(596),
#  np.int64(608),
#  np.int64(648),
#  np.int64(661),
#  np.int64(673),
#  np.int64(733),
#  np.int64(736),
#  np.int64(780),
#  np.int64(804),
#  np.int64(919),
#  np.int64(923),
#  np.int64(940),
#  np.int64(943),
#  np.int64(954),
#  np.int64(1009),
#  np.int64(1023),
#  np.int64(1024),
#  np.int64(1025),
#  np.int64(1029),
#  np.int64(1030),
# ...

# %%
num_items
# Out:
# np.int64(193610)
